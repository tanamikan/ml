# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

base_path = '/content/drive/MyDrive/x_ray_chest/results/yolo'
ver = 'v1'

# 新しいフォルダを生成
weight_folder = 'weight'
train_folder = 'train'
test_folder = 'test'
test_img_folder = 'images'

weight_folder_path = os.path.join(base_path, ver, weight_folder)
train_folder_path = os.path.join(base_path, ver, train_folder)
test_folder_path = os.path.join(base_path, ver, test_folder)
test_img_path = os.path.join(base_path, ver, test_folder, test_img_folder)

# %%
import sys
sys.path.append('/content/drive/MyDrive/x_ray_chest/lib/ultralytics-main')

# %%
from ultralytics.models import YOLO

# %%
# Load a model
model = YOLO("yolov8x.pt")  # load a pretrained model (recommended for training)

# %%
# Use the model
model.train(data="/content/drive/MyDrive/x_ray_chest/notebook/yolo/v1/yolo_v1.yaml",
            epochs=200,
            save_period=1,
            patience=0,
            optimizer='Adam',
            seed=0,
            lr0=0.001,
            lrf=0.001,
            name='/content/drive/MyDrive/x_ray_chest/results/yolo/v1/weight')
# Out:
# Ultralytics YOLOv8.0.232 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# ...

# %%
import pandas as pd
import os

loss_file_path = '/content/drive/MyDrive/x_ray_chest/results/yolo/v1/weight/results.csv'

loss_df = pd.read_csv(loss_file_path, encoding='utf-8')

loss_df.replace('                    nan', '', inplace=True)

print(loss_df.head())
# Out:
#                      epoch           train/box_loss           train/cls_loss  \
# 0                        1                   2.6886                   5.1657
# 1                        2                   2.5202                   4.2851
# 2                        3                   2.5223                   4.2934
# 3                        4                   2.4998                   4.1656
# 4                        5                   2.4339                   4.0542
#
#             train/dfl_loss     metrics/precision(B)        metrics/recall(B)  \
# 0                   2.6697                  0.00031                  0.04503
# 1                   2.6742                  0.00031                  0.04503
# 2                   2.6757                  0.12690                  0.03542
# 3                   2.6402                  0.62719                  0.01042
# 4                   2.5715                  0.68230                  0.02083
#
# ...

# %%
loss_df['train_loss_sum'] = loss_df.iloc[:, 1] + loss_df.iloc[:, 2] + loss_df.iloc[:, 3]
loss_df['val_loss_sum'] = pd.to_numeric(loss_df.iloc[:, 8]) + pd.to_numeric(loss_df.iloc[:, 9]) + pd.to_numeric(loss_df.iloc[:, 10])

loss_df.head()
# Out:
#                      epoch           train/box_loss           train/cls_loss  \
# 0                        1                   2.6886                   5.1657
# 1                        2                   2.5202                   4.2851
# 2                        3                   2.5223                   4.2934
# 3                        4                   2.4998                   4.1656
# 4                        5                   2.4339                   4.0542
#
#             train/dfl_loss     metrics/precision(B)        metrics/recall(B)  \
# 0                   2.6697                  0.00031                  0.04503
# 1                   2.6742                  0.00031                  0.04503
# 2                   2.6757                  0.12690                  0.03542
# 3                   2.6402                  0.62719                  0.01042
# 4                   2.5715                  0.68230                  0.02083
#
# ...

# %%
min_val_value = loss_df['val_loss_sum'].min()

min_index = loss_df.index[loss_df['val_loss_sum'] == min_val_value]
min_epoch = loss_df.iloc[min_index, 0].values[0]

print(f'min_epoch: {min_epoch}, min_val_value: {min_val_value}')
# Out:
# min_epoch: 38, min_val_value: 7.7774

# %%
from matplotlib import pyplot as plt
import numpy as np

# 全体設定
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.rcParams['xtick.major.width'] = 1.2
plt.rcParams['ytick.major.width'] = 1.2
plt.rcParams['font.size'] = 12
plt.rcParams['axes.linewidth'] = 1.2
plt.rcParams['axes.grid']=True
plt.rcParams['grid.linestyle']='--'
plt.rcParams['grid.linewidth'] = 0.3
plt.rcParams["legend.markerscale"] = 2
plt.rcParams["legend.fancybox"] = False
plt.rcParams["legend.framealpha"] = 1
plt.rcParams["legend.edgecolor"] = 'black'

fig = plt.figure()

ax1 = fig.subplots()
ax2 = ax1.twinx()

ax1.plot(loss_df.iloc[:, 0], loss_df['train_loss_sum'], color="blue", label="train loss")
ax2.plot(loss_df.iloc[:, 0], loss_df['val_loss_sum'], c="r", label="val loss")

ax1.set_xlim(0, 200)
ax1.set_ylim(0, 14)
ax1.set_xlabel('epochs')
ax1.set_ylabel('train loss')

ax2.set_xlim(0, 200)
ax2.set_ylim(0, 14)
ax2.set_xlabel('epochs')
ax2.set_ylabel('val loss')

plt.grid(color = "gray", linestyle="dotted")

plt.title("train loss, val loss vs epochs")
h1, l1 = ax1.get_legend_handles_labels()
h2, l2 = ax2.get_legend_handles_labels()
ax1.legend(h1 + h2, l1 + l2)

plt.show()

# %%
import pandas as pd
import os

loss_file_path = '/content/drive/MyDrive/x_ray_chest/results/yolo/v1/train/results/results.csv'

loss_df = pd.read_csv(loss_file_path, encoding='utf-8')

loss_df.replace('                    nan', '', inplace=True)

print(loss_df.head())
# Out:
#                      epoch           train/box_loss           train/cls_loss  \
# 0                        1                   2.6886                   5.1657
# 1                        2                   2.5202                   4.2851
# 2                        3                   2.5223                   4.2934
# 3                        4                   2.4998                   4.1656
# 4                        5                   2.4339                   4.0542
#
#             train/dfl_loss     metrics/precision(B)        metrics/recall(B)  \
# 0                   2.6697                  0.00031                  0.04503
# 1                   2.6742                  0.00031                  0.04503
# 2                   2.6757                  0.12690                  0.03542
# 3                   2.6402                  0.62719                  0.01042
# 4                   2.5715                  0.68230                  0.02083
#
# ...

# %%
from matplotlib import pyplot as plt
import numpy as np

# 全体設定
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.rcParams['xtick.major.width'] = 1.2
plt.rcParams['ytick.major.width'] = 1.2
plt.rcParams['font.size'] = 12
plt.rcParams['axes.linewidth'] = 1.2
plt.rcParams['axes.grid']=True
plt.rcParams['grid.linestyle']='--'
plt.rcParams['grid.linewidth'] = 0.3
plt.rcParams["legend.markerscale"] = 2
plt.rcParams["legend.fancybox"] = False
plt.rcParams["legend.framealpha"] = 1
plt.rcParams["legend.edgecolor"] = 'black'

fig = plt.figure()

ax1 = fig.subplots()

ax1.plot(loss_df.iloc[:, 0], loss_df.iloc[:, 6]*100, color="steelblue", label="train loss")

ax1.set_xlim(0, 200)
ax1.set_ylim(0, 30)
ax1.set_xlabel('epochs')
ax1.set_ylabel('mAP')
ax1.set_title('mAP for val data vs epoch')

plt.grid(color = "gray", linestyle="dotted")

plt.show()
